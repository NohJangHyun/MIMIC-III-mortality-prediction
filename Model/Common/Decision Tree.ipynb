# %%
import optuna
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# 데이터 불러오기
train_data = pd.read_csv("~/project/MIMIC-III/Baseline/overlap/OSI/overlap_OSI(1%)_train.csv")
test_data = pd.read_csv("~/project/MIMIC-III/Baseline/overlap/OSI/overlap_OSI(1%)_test.csv")

# Overlap ARDS
ARDS = pd.read_csv("~/project/MIMIC-III/ARDS.csv")
ARDS.drop("y", axis=1, inplace=True)

train_data = pd.merge(train_data, ARDS, on=['SUBJECT_ID', 'HADM_ID'], how='inner')
test_data = pd.merge(test_data, ARDS, on=['SUBJECT_ID', 'HADM_ID'], how='inner')


train_data.drop(["SUBJECT_ID","HADM_ID", "DOA", "TLOS", "ETHNICITY"], axis=1, inplace=True)
test_data.drop(["SUBJECT_ID","HADM_ID", "DOA", "TLOS", "ETHNICITY"], axis=1, inplace=True)

train_data = pd.get_dummies(train_data, columns=["GENDER"])
test_data = pd.get_dummies(test_data, columns=["GENDER"])

# train_data와 test_data의 칼럼을 맞추기 위해 차집합을 계산
missing_columns_in_test = set(train_data.columns) - set(test_data.columns)
missing_columns_in_train = set(test_data.columns) - set(train_data.columns)

# test_data에 train_data의 더미 변수를 추가하고 0으로 채워주기
for col in missing_columns_in_test:
    test_data[col] = 0

# train_data에 test_data의 더미 변수를 추가하고 0으로 채워주기
for col in missing_columns_in_train:
    train_data[col] = 0
    
####################################################################
# Down Sampling
# train 데이터의 레이블 비율 확인
train_labels = train_data['y']
label_counts = train_labels.value_counts()

# train 데이터의 레이블 비율이 1:1이 되도록 분할
class_0_data = train_data[train_data['y'] == 0]
class_1_data = train_data[train_data['y'] == 1]

# 레이블이 0인 데이터 중에서 샘플 개수가 적은 만큼만 선택
num_samples = min(label_counts[0], label_counts[1])
class_0_data = class_0_data.sample(num_samples, random_state=42)

# 레이블이 1인 데이터 중에서 샘플 개수가 적은 만큼만 선택
class_1_data = class_1_data.sample(num_samples, random_state=42)

# 선택한 데이터를 결합하여 최종 train 데이터 생성
train_data = pd.concat([class_0_data, class_1_data])
####################################################################


# Features와 Target 설정
X_train = train_data.drop('y', axis=1)
y_train = train_data['y']
X_test = test_data.drop('y', axis=1)

print("train shape\n",X_train.shape,"\n")
print("train shape\n",X_test.shape,"\n")

target = "y"
features = [f for f in train_data.columns if f not in [target]]

print("train value\n",train_data['y'].value_counts())
print("test value\n",test_data['y'].value_counts())
# Out:
# train shape
#  (2298, 55)
#
# train shape
#  (1421, 55)
#
# train value
#  0    1149
# 1    1149
# Name: y, dtype: int64
# test value
#  0    1037
# 1     384
# Name: y, dtype: int64

# %%
# Objective 함수 정의
def objective(trial):
    max_depth = trial.suggest_int("max_depth", 2, 10)
    min_samples_split = trial.suggest_float("min_samples_split", 0.1, 1.0)
    min_samples_leaf = trial.suggest_float("min_samples_leaf", 0.1, 0.5)
    
    model = DecisionTreeClassifier(
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        random_state=42
    )
    
    # Cross Validation을 활용한 평가 지표 계산
    scores = cross_val_score(model, X_train, y_train, cv=5, scoring="accuracy")
    return scores.mean()

# Optuna를 활용한 Hyperparameter tuning
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100, show_progress_bar=True)

# 최적의 Hyperparameter로 모델 학습
best_params = study.best_params
best_model = DecisionTreeClassifier(
    max_depth=best_params["max_depth"],
    min_samples_split=best_params["min_samples_split"],
    min_samples_leaf=best_params["min_samples_leaf"],
    random_state=42
)
best_model.fit(X_train, y_train)
# Out:
# [I 2023-09-06 14:59:18,101] A new study created in memory with name: no-name-00afda05-c072-4a3a-9f0e-8a5b04248385
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2023-09-06 14:59:18,172] Trial 0 finished with value: 0.5635294117647058 and parameters: {'max_depth': 8, 'min_samples_split': 0.3435184243353236, 'min_samples_leaf': 0.29717452644613207}. Best is trial 0 with value: 0.5635294117647058.
# [I 2023-09-06 14:59:18,232] Trial 1 finished with value: 0.5713602349152221 and parameters: {'max_depth': 6, 'min_samples_split': 0.3828628943604597, 'min_samples_leaf': 0.13205209533610962}. Best is trial 1 with value: 0.5713602349152221.
# [I 2023-09-06 14:59:18,272] Trial 2 finished with value: 0.5717902813299233 and parameters: {'max_depth': 9, 'min_samples_split': 0.7025622229453975, 'min_samples_leaf': 0.2692009070843995}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:18,312] Trial 3 finished with value: 0.5717902813299233 and parameters: {'max_depth': 8, 'min_samples_split': 0.7773596834637235, 'min_samples_leaf': 0.14431006911484734}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:18,401] Trial 4 finished with value: 0.5700530453727385 and parameters: {'max_depth': 8, 'min_samples_split': 0.3807990209299049, 'min_samples_leaf': 0.12305611863156601}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:18,505] Trial 5 finished with value: 0.5617902813299231 and parameters: {'max_depth': 5, 'min_samples_split': 0.5441943293699976, 'min_samples_leaf': 0.14114429250133617}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:18,586] Trial 6 finished with value: 0.5639604054182059 and parameters: {'max_depth': 9, 'min_samples_split': 0.9715400256882933, 'min_samples_leaf': 0.49367920008363775}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:18,642] Trial 7 finished with value: 0.5617902813299234 and parameters: {'max_depth': 5, 'min_samples_split': 0.6336051141230691, 'min_samples_leaf': 0.3989125104428375}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:18,691] Trial 8 finished with value: 0.5617902813299234 and parameters: {'max_depth': 7, 'min_samples_split': 0.21586954731269986, 'min_samples_leaf': 0.41196921075281623}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:18,742] Trial 9 finished with value: 0.5661381074168798 and parameters: {'max_depth': 3, 'min_samples_split': 0.8594606934932598, 'min_samples_leaf': 0.34487510834971213}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:18,822] Trial 10 finished with value: 0.5617950175239178 and parameters: {'max_depth': 10, 'min_samples_split': 0.10933491204660756, 'min_samples_leaf': 0.22795887985736266}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:18,903] Trial 11 finished with value: 0.5717902813299233 and parameters: {'max_depth': 10, 'min_samples_split': 0.7702221001541031, 'min_samples_leaf': 0.22234307902371786}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:18,981] Trial 12 finished with value: 0.5717902813299233 and parameters: {'max_depth': 8, 'min_samples_split': 0.7010949865034994, 'min_samples_leaf': 0.20887081600130442}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:19,055] Trial 13 finished with value: 0.5717902813299233 and parameters: {'max_depth': 2, 'min_samples_split': 0.8411609171906935, 'min_samples_leaf': 0.2856914212245508}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:19,182] Trial 14 finished with value: 0.5617902813299231 and parameters: {'max_depth': 9, 'min_samples_split': 0.5981059021531409, 'min_samples_leaf': 0.179687583739094}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:19,255] Trial 15 finished with value: 0.5717902813299233 and parameters: {'max_depth': 7, 'min_samples_split': 0.7396762874291816, 'min_samples_leaf': 0.25638102459412465}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:19,316] Trial 16 finished with value: 0.5639689305673959 and parameters: {'max_depth': 9, 'min_samples_split': 0.5227283497354952, 'min_samples_leaf': 0.18016280589364786}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:19,372] Trial 17 finished with value: 0.5717902813299233 and parameters: {'max_depth': 6, 'min_samples_split': 0.987621415387393, 'min_samples_leaf': 0.10166845795819768}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:19,443] Trial 18 finished with value: 0.5717902813299233 and parameters: {'max_depth': 7, 'min_samples_split': 0.6790450926950207, 'min_samples_leaf': 0.16435519926433212}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:19,517] Trial 19 finished with value: 0.5717902813299233 and parameters: {'max_depth': 10, 'min_samples_split': 0.830226047376563, 'min_samples_leaf': 0.26073045781810555}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:19,587] Trial 20 finished with value: 0.5717902813299233 and parameters: {'max_depth': 4, 'min_samples_split': 0.5130876759284237, 'min_samples_leaf': 0.3215649302610514}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:19,641] Trial 21 finished with value: 0.5717902813299233 and parameters: {'max_depth': 10, 'min_samples_split': 0.7728356563111807, 'min_samples_leaf': 0.21778625295507406}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:19,713] Trial 22 finished with value: 0.5717902813299233 and parameters: {'max_depth': 9, 'min_samples_split': 0.782981892292256, 'min_samples_leaf': 0.1871403259941809}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:19,782] Trial 23 finished with value: 0.5717902813299233 and parameters: {'max_depth': 10, 'min_samples_split': 0.6781867816148429, 'min_samples_leaf': 0.23864442381108555}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:19,844] Trial 24 finished with value: 0.5717902813299233 and parameters: {'max_depth': 8, 'min_samples_split': 0.8922150857346213, 'min_samples_leaf': 0.21158631259502073}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:19,895] Trial 25 finished with value: 0.5717902813299233 and parameters: {'max_depth': 9, 'min_samples_split': 0.7534367636531623, 'min_samples_leaf': 0.15574716758796148}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:19,941] Trial 26 finished with value: 0.5717902813299233 and parameters: {'max_depth': 10, 'min_samples_split': 0.9140564445904555, 'min_samples_leaf': 0.26274235193618406}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:19,998] Trial 27 finished with value: 0.5717902813299233 and parameters: {'max_depth': 8, 'min_samples_split': 0.8206991946131305, 'min_samples_leaf': 0.18857847274497266}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:20,070] Trial 28 finished with value: 0.5652685421994885 and parameters: {'max_depth': 7, 'min_samples_split': 0.6262604779846006, 'min_samples_leaf': 0.1066712995635194}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:20,129] Trial 29 finished with value: 0.5717902813299233 and parameters: {'max_depth': 8, 'min_samples_split': 0.728468987752469, 'min_samples_leaf': 0.1508879499871233}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:20,196] Trial 30 finished with value: 0.5717902813299233 and parameters: {'max_depth': 9, 'min_samples_split': 0.9177581787335735, 'min_samples_leaf': 0.23968307199377903}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:20,261] Trial 31 finished with value: 0.5717902813299233 and parameters: {'max_depth': 9, 'min_samples_split': 0.7264847857636252, 'min_samples_leaf': 0.20474433132589476}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:20,323] Trial 32 finished with value: 0.5717902813299233 and parameters: {'max_depth': 8, 'min_samples_split': 0.6811858411616135, 'min_samples_leaf': 0.2073200525499983}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:20,368] Trial 33 finished with value: 0.5717902813299233 and parameters: {'max_depth': 8, 'min_samples_split': 0.7978954345854848, 'min_samples_leaf': 0.1268007892494324}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:20,426] Trial 34 finished with value: 0.5617902813299231 and parameters: {'max_depth': 6, 'min_samples_split': 0.5947923035753684, 'min_samples_leaf': 0.16141946521580255}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:20,488] Trial 35 finished with value: 0.5639689305673959 and parameters: {'max_depth': 7, 'min_samples_split': 0.4775109021451483, 'min_samples_leaf': 0.12647428313791792}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:20,540] Trial 36 finished with value: 0.5717902813299233 and parameters: {'max_depth': 10, 'min_samples_split': 0.6717912367699361, 'min_samples_leaf': 0.28386492876992486}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:20,603] Trial 37 finished with value: 0.5717902813299233 and parameters: {'max_depth': 5, 'min_samples_split': 0.7900781058593256, 'min_samples_leaf': 0.14206695183347146}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:20,656] Trial 38 finished with value: 0.5717902813299233 and parameters: {'max_depth': 8, 'min_samples_split': 0.7091708638433678, 'min_samples_leaf': 0.22829531048098056}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:20,704] Trial 39 finished with value: 0.5717902813299233 and parameters: {'max_depth': 9, 'min_samples_split': 0.870970877549168, 'min_samples_leaf': 0.2026976506881856}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:20,766] Trial 40 finished with value: 0.5639641943734015 and parameters: {'max_depth': 6, 'min_samples_split': 0.6323486189160196, 'min_samples_leaf': 0.24523632405347123}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:20,813] Trial 41 finished with value: 0.5717902813299233 and parameters: {'max_depth': 3, 'min_samples_split': 0.8340177733149161, 'min_samples_leaf': 0.2837225159463366}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:20,864] Trial 42 finished with value: 0.5717902813299233 and parameters: {'max_depth': 2, 'min_samples_split': 0.7676108737886587, 'min_samples_leaf': 0.29948019161538664}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:20,913] Trial 43 finished with value: 0.5717902813299233 and parameters: {'max_depth': 4, 'min_samples_split': 0.8421899703003473, 'min_samples_leaf': 0.26630190690862177}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:20,969] Trial 44 finished with value: 0.5717902813299233 and parameters: {'max_depth': 2, 'min_samples_split': 0.7299811456845626, 'min_samples_leaf': 0.31650399961682263}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:21,021] Trial 45 finished with value: 0.5717902813299233 and parameters: {'max_depth': 7, 'min_samples_split': 0.948301042044519, 'min_samples_leaf': 0.2296377596374743}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:21,076] Trial 46 finished with value: 0.5717902813299233 and parameters: {'max_depth': 5, 'min_samples_split': 0.8615921904281771, 'min_samples_leaf': 0.27663922749243475}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:21,137] Trial 47 finished with value: 0.5717902813299233 and parameters: {'max_depth': 9, 'min_samples_split': 0.8109575869287037, 'min_samples_leaf': 0.17178006351257993}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:21,209] Trial 48 finished with value: 0.5717902813299233 and parameters: {'max_depth': 10, 'min_samples_split': 0.762398468017008, 'min_samples_leaf': 0.1924126050907347}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:21,274] Trial 49 finished with value: 0.5717902813299233 and parameters: {'max_depth': 3, 'min_samples_split': 0.8748927211528037, 'min_samples_leaf': 0.2493242948265389}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:21,334] Trial 50 finished with value: 0.5717902813299233 and parameters: {'max_depth': 8, 'min_samples_split': 0.7066492804996671, 'min_samples_leaf': 0.1780227490050904}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:21,382] Trial 51 finished with value: 0.5717902813299233 and parameters: {'max_depth': 7, 'min_samples_split': 0.7482274916968432, 'min_samples_leaf': 0.22182540025256492}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:21,434] Trial 52 finished with value: 0.5717902813299233 and parameters: {'max_depth': 8, 'min_samples_split': 0.7872911842771885, 'min_samples_leaf': 0.25724097341246593}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:21,488] Trial 53 finished with value: 0.5717902813299233 and parameters: {'max_depth': 7, 'min_samples_split': 0.8119906065331768, 'min_samples_leaf': 0.2424252685077591}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:21,558] Trial 54 finished with value: 0.5639641943734015 and parameters: {'max_depth': 9, 'min_samples_split': 0.6598846294261557, 'min_samples_leaf': 0.27942513801474667}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:21,626] Trial 55 finished with value: 0.5717902813299233 and parameters: {'max_depth': 6, 'min_samples_split': 0.7046398050816903, 'min_samples_leaf': 0.22051286415416377}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:21,707] Trial 56 finished with value: 0.5717902813299233 and parameters: {'max_depth': 8, 'min_samples_split': 0.7423952988188073, 'min_samples_leaf': 0.3048005316531998}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:21,767] Trial 57 finished with value: 0.5717902813299233 and parameters: {'max_depth': 9, 'min_samples_split': 0.8444679221484286, 'min_samples_leaf': 0.26913807352249197}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:21,836] Trial 58 finished with value: 0.554833759590793 and parameters: {'max_depth': 10, 'min_samples_split': 0.5940560085968033, 'min_samples_leaf': 0.25582235472303594}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:21,902] Trial 59 finished with value: 0.5717902813299233 and parameters: {'max_depth': 7, 'min_samples_split': 0.7667377142866583, 'min_samples_leaf': 0.19334986584601968}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:21,965] Trial 60 finished with value: 0.5661381074168798 and parameters: {'max_depth': 6, 'min_samples_split': 0.8931259527895035, 'min_samples_leaf': 0.3379942707574461}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:22,021] Trial 61 finished with value: 0.5717902813299233 and parameters: {'max_depth': 4, 'min_samples_split': 0.9549012614727642, 'min_samples_leaf': 0.10894785832615278}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:22,070] Trial 62 finished with value: 0.5717902813299233 and parameters: {'max_depth': 8, 'min_samples_split': 0.9739276316599513, 'min_samples_leaf': 0.11492222915798778}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:22,119] Trial 63 finished with value: 0.5717902813299233 and parameters: {'max_depth': 9, 'min_samples_split': 0.989438825176102, 'min_samples_leaf': 0.13915837355492777}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:22,173] Trial 64 finished with value: 0.5717902813299233 and parameters: {'max_depth': 7, 'min_samples_split': 0.931633259807755, 'min_samples_leaf': 0.15650385435123143}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:22,235] Trial 65 finished with value: 0.5717902813299233 and parameters: {'max_depth': 5, 'min_samples_split': 0.898897981110006, 'min_samples_leaf': 0.10219299137946565}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:22,301] Trial 66 finished with value: 0.5717902813299233 and parameters: {'max_depth': 10, 'min_samples_split': 0.8077945820422284, 'min_samples_leaf': 0.1202612215895515}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:22,371] Trial 67 finished with value: 0.5717902813299233 and parameters: {'max_depth': 9, 'min_samples_split': 0.9945796892068596, 'min_samples_leaf': 0.1417086961494504}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:22,445] Trial 68 finished with value: 0.5717902813299233 and parameters: {'max_depth': 10, 'min_samples_split': 0.8336807395091821, 'min_samples_leaf': 0.17241368437983745}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:22,500] Trial 69 finished with value: 0.5717902813299233 and parameters: {'max_depth': 3, 'min_samples_split': 0.9122089929015711, 'min_samples_leaf': 0.21121583112964715}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:22,569] Trial 70 finished with value: 0.5717902813299233 and parameters: {'max_depth': 8, 'min_samples_split': 0.7860014859842319, 'min_samples_leaf': 0.10027070305647466}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:22,641] Trial 71 finished with value: 0.5717902813299233 and parameters: {'max_depth': 7, 'min_samples_split': 0.6923647025361735, 'min_samples_leaf': 0.12837883106480552}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:22,705] Trial 72 finished with value: 0.5639641943734015 and parameters: {'max_depth': 6, 'min_samples_split': 0.6536913159300222, 'min_samples_leaf': 0.23340413679760452}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:22,757] Trial 73 finished with value: 0.5717902813299233 and parameters: {'max_depth': 8, 'min_samples_split': 0.7346365876753452, 'min_samples_leaf': 0.16341444592913196}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:22,805] Trial 74 finished with value: 0.5717902813299233 and parameters: {'max_depth': 7, 'min_samples_split': 0.7184837632074982, 'min_samples_leaf': 0.14330663846037303}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:22,856] Trial 75 finished with value: 0.5717902813299233 and parameters: {'max_depth': 9, 'min_samples_split': 0.6723337830793026, 'min_samples_leaf': 0.11769651188120428}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:22,904] Trial 76 finished with value: 0.5717902813299233 and parameters: {'max_depth': 7, 'min_samples_split': 0.6947962339505948, 'min_samples_leaf': 0.24897286322449075}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:22,970] Trial 77 finished with value: 0.5717902813299233 and parameters: {'max_depth': 8, 'min_samples_split': 0.754031756463948, 'min_samples_leaf': 0.18494449644685584}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:23,040] Trial 78 finished with value: 0.5717902813299233 and parameters: {'max_depth': 6, 'min_samples_split': 0.7735193740186009, 'min_samples_leaf': 0.19604127931479862}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:23,099] Trial 79 finished with value: 0.5717902813299233 and parameters: {'max_depth': 2, 'min_samples_split': 0.8691557206498356, 'min_samples_leaf': 0.20508901172363242}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:23,168] Trial 80 finished with value: 0.5717902813299233 and parameters: {'max_depth': 8, 'min_samples_split': 0.7215270942762855, 'min_samples_leaf': 0.23602755282681387}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:23,233] Trial 81 finished with value: 0.5717902813299233 and parameters: {'max_depth': 10, 'min_samples_split': 0.8198614954581273, 'min_samples_leaf': 0.2690736708363991}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:23,306] Trial 82 finished with value: 0.5717902813299233 and parameters: {'max_depth': 10, 'min_samples_split': 0.7949323204072329, 'min_samples_leaf': 0.2898572817284087}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:23,379] Trial 83 finished with value: 0.5717902813299233 and parameters: {'max_depth': 10, 'min_samples_split': 0.8501977522872664, 'min_samples_leaf': 0.2587209435548576}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:23,457] Trial 84 finished with value: 0.5717902813299233 and parameters: {'max_depth': 9, 'min_samples_split': 0.7498749122345072, 'min_samples_leaf': 0.22579365736775048}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:23,590] Trial 85 finished with value: 0.5717902813299233 and parameters: {'max_depth': 10, 'min_samples_split': 0.8237955142926041, 'min_samples_leaf': 0.21371495151702405}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:23,716] Trial 86 finished with value: 0.5717902813299233 and parameters: {'max_depth': 9, 'min_samples_split': 0.7760631707636675, 'min_samples_leaf': 0.24262523848839768}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:23,806] Trial 87 finished with value: 0.5717902813299233 and parameters: {'max_depth': 7, 'min_samples_split': 0.7011732226638171, 'min_samples_leaf': 0.2726640375667884}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:23,873] Trial 88 finished with value: 0.5717902813299233 and parameters: {'max_depth': 9, 'min_samples_split': 0.732946715022826, 'min_samples_leaf': 0.2615675252771153}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:23,944] Trial 89 finished with value: 0.5717902813299233 and parameters: {'max_depth': 4, 'min_samples_split': 0.7967510400725408, 'min_samples_leaf': 0.288260425425915}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:24,021] Trial 90 finished with value: 0.5630946291560102 and parameters: {'max_depth': 5, 'min_samples_split': 0.6469491967114521, 'min_samples_leaf': 0.25130344469767585}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:24,076] Trial 91 finished with value: 0.5717902813299233 and parameters: {'max_depth': 3, 'min_samples_split': 0.679462156125691, 'min_samples_leaf': 0.15415726132512328}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:24,138] Trial 92 finished with value: 0.5717902813299233 and parameters: {'max_depth': 4, 'min_samples_split': 0.871906714541182, 'min_samples_leaf': 0.13561463277748326}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:24,196] Trial 93 finished with value: 0.5639641943734015 and parameters: {'max_depth': 6, 'min_samples_split': 0.6192856408176731, 'min_samples_leaf': 0.2756818601375571}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:24,267] Trial 94 finished with value: 0.5717902813299233 and parameters: {'max_depth': 2, 'min_samples_split': 0.8483546356771892, 'min_samples_leaf': 0.2210525618310079}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:24,322] Trial 95 finished with value: 0.5717902813299233 and parameters: {'max_depth': 5, 'min_samples_split': 0.7504062072989233, 'min_samples_leaf': 0.3085000263885499}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:24,373] Trial 96 finished with value: 0.5717902813299233 and parameters: {'max_depth': 8, 'min_samples_split': 0.768367885555388, 'min_samples_leaf': 0.295684296829452}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:24,423] Trial 97 finished with value: 0.5717902813299233 and parameters: {'max_depth': 3, 'min_samples_split': 0.801687042447709, 'min_samples_leaf': 0.16695852584763282}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:24,475] Trial 98 finished with value: 0.5717902813299233 and parameters: {'max_depth': 10, 'min_samples_split': 0.7195021882440432, 'min_samples_leaf': 0.18274876871262105}. Best is trial 2 with value: 0.5717902813299233.
# [I 2023-09-06 14:59:24,537] Trial 99 finished with value: 0.5717902813299233 and parameters: {'max_depth': 8, 'min_samples_split': 0.8263444952110848, 'min_samples_leaf': 0.12647041281987284}. Best is trial 2 with value: 0.5717902813299233.
# DecisionTreeClassifier(max_depth=9, min_samples_leaf=0.2692009070843995,
#                        min_samples_split=0.7025622229453975, random_state=42)

# %%
# # Test 데이터로 모델 평가
# y_pred = best_model.predict(X_test)
# accuracy = accuracy_score(test_data['y'], y_pred)
# precision = precision_score(test_data['y'], y_pred)
# recall = recall_score(test_data['y'], y_pred)
# f1 = f1_score(test_data['y'], y_pred)

# print("Accuracy:", accuracy)
# print("Precision:", precision)
# print("Recall:", recall)
# print("F1-score:", f1)

# %%
# Test 데이터로 모델 평가
y_pred = best_model.predict(X_test)
accuracy = accuracy_score(test_data['y'], y_pred)
precision = precision_score(test_data['y'], y_pred)
recall = recall_score(test_data['y'], y_pred)
f1 = f1_score(test_data['y'], y_pred)
auroc = roc_auc_score(test_data['y'], y_pred)

rounded_accuracy = round(accuracy * 100, 2)
rounded_precision = round(precision * 100, 2)
rounded_recall = round(recall * 100, 2)
rounded_f1 = round(f1 * 100, 2)
rounded_auroc = round(auroc * 100, 2)

print("Test Accuracy:", rounded_accuracy)
print("Precision:", rounded_precision)
print("Recall:", rounded_recall)
print("F1-score:", rounded_f1)
print("AUROC:", rounded_auroc)
# print(accuracy)
# print(recall)
# print(f1)

# Confusion Matrix 계산
cm = confusion_matrix(test_data['y'], y_pred)

# Confusion Matrix 시각화
cm_df = pd.DataFrame(cm, index=['Actual 0', 'Actual 1'], columns=['Predicted 0', 'Predicted 1'])
plt.figure(figsize=(6, 4))
sns.heatmap(cm_df, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.show()

# Classification Report 출력
print("Classification Report:")
print(classification_report(test_data['y'], y_pred))

# Precision-Recall Curve 계산 및 시각화
precision, recall, _ = precision_recall_curve(test_data['y'], best_model.predict_proba(X_test)[:, 1])
average_precision = auc(recall, precision)
plt.figure()
plt.step(recall, precision, color='b', alpha=0.2, where='post')
plt.fill_between(recall, precision, step='post', alpha=0.2, color='b')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title(f'Precision-Recall Curve (AP = {average_precision:.2f})')
plt.show()

# Feature Importance 계산
feature_importance = best_model.feature_importances_

# Feature Importance 시각화
plt.figure(figsize=(10, 6))
sns.barplot(x=feature_importance, y=features)
plt.title('Feature Importance')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()
# Out:
# Test Accuracy: 49.61
# Precision: 30.88
# Recall: 69.79
# F1-score: 42.81
# AUROC: 55.97
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.42      0.55      1037
#            1       0.31      0.70      0.43       384
#
#     accuracy                           0.50      1421
#    macro avg       0.55      0.56      0.49      1421
# weighted avg       0.66      0.50      0.52      1421
